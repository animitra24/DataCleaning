# %% [markdown]
# # Variable Transformation
# 1. Logarithmic
# 2. Exponential
# 3. Reciprocal
# 4. Sqaure Root Tansformation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\Anindita Mitra\Dataset\Titanic\tested.csv',usecols=['Age','Fare','Survived'])
data.head()
# Out:
#    Survived   Age     Fare
# 0         0  34.5   7.8292
# 1         1  47.0   7.0000
# 2         0  62.0   9.6875
# 3         0  27.0   8.6625
# 4         1  22.0  12.2875

# %%
data.isnull().sum()
# Out:
# Survived     0
# Age         86
# Fare         1
# dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.heatmap(data.isnull())

# %%
#Filling Missing Value for Age
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
#Filling Missing Value for Fare
data['Fare']=data['Fare'].fillna(data['Fare'].mean())

# %%
data.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.heatmap(data.isnull())

# %% [markdown]
# ### Q-Q Plot

# %% [markdown]
# The quantile-quantile (q-q) plot is a graphical technique for determining if two data sets come from populations with a common distribution. A q-q plot is a plot of the quantiles of the first data set against the quantiles of the second data set.

# %%
def diagnostic_plots(df, variable):
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
diagnostic_plots(data, 'Age')

# %%
diagnostic_plots(data, 'Fare')

# %% [markdown]
# ### Logarithmic Transformation

# %% [markdown]
# The log transformation is, arguably, the most popular among the different types of transformations used to transform skewed data to approximately conform to normality. If the original data follows a log-normal distribution or approximately so, then the log-transformed data follows a normal or near normal distribution.

# %%
#if u have any data wth value "zero" that time you wont find log of Zero
data['Log_Fare']=np.log(data['Fare']+1)
diagnostic_plots(data,'Log_Fare')

# %% [markdown]
# ### Reciprocal transformation

# %%
data['Rec_Fare']=1/(data['Fare']+1)
diagnostic_plots(data,'Rec_Fare')

# %% [markdown]
# ### Sqaure Root Tansformation

# %%
data['sqr_Fare']=data['Fare']**(1/2)
diagnostic_plots(data,'sqr_Fare')
